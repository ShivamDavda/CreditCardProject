# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 

df = pd.read_csv(r"C:\Users\Shivam\Downloads\New folder (100)\CC GENERAL.csv")
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df.rename(columns={'purchases_installments_frequency': 'PIF'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
num_cols = ['CREDIT_LIMIT', 'PURCHASES', 'BALANCE']

for col in num_cols:
    plt.figure(figsize=(7, 4))
    sns.histplot(df[col], kde=True, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
sns.scatterplot(x='BALANCE',y='PURCHASES',data=df,color='blue')
plt.title('Balance vs Purchase')
plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
df = pd.read_csv(r"C:\Users\Shivam\Downloads\New folder (100)\CC GENERAL.csv")
sns.scatterplot(x='BALANCE',y='PURCHASES',data=df,color='blue')
plt.title('Balance vs Purchase')
plt.show()

# %%
def spendinglevel(purchase):
    if purchase < 500:
        return 'low'
    elif purchase < 2000:
        return 'Medium'
    else: 
        'high'
df['Purchase_level'] = df['PURCHASES'].apply(spendinglevel)

# %%
print(df['Purchase_level'])
# Out:
# 0          low
# 1          low
# 2       Medium
# 3       Medium
# 4          low
#          ...
# 8945       low
# 8946       low
# 8947       low
# 8948       low
# 8949    Medium
# Name: Purchase_level, Length: 8950, dtype: object

# %%
df['Payment_flag']=df['PRC_FULL_PAYMENT'].apply(lambda x:'Yes' if x==1 else 'No')
print(df['Payment_flag'])
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#         ..
# 8945    No
# 8946    No
# 8947    No
# 8948    No
# 8949    No
# Name: Payment_flag, Length: 8950, dtype: object

# %%
df['Utilized_limit']=df['BALANCE']/df['CREDIT_LIMIT']
df['Utilized_limit']
# Out:
# 0       0.040901
# 1       0.457495
# 2       0.332687
# 3       0.222223
# 4       0.681429
#           ...
# 8945    0.028494
# 8946    0.019183
# 8947    0.023399
# 8948    0.026915
# 8949    0.310590
# Name: Utilized_limit, Length: 8950, dtype: float64

# %%
df['Cashadvance_lable']=df['CASH_ADVANCE'].apply(lambda x:'Yes' if x>1 else 'No')
df['Cashadvance_lable']
# Out:
# 0        No
# 1       Yes
# 2        No
# 3       Yes
# 4        No
#        ...
# 8945     No
# 8946     No
# 8947     No
# 8948    Yes
# 8949    Yes
# Name: Cashadvance_lable, Length: 8950, dtype: object

# %%
df['Active_puchase']=df['PURCHASES'].apply(lambda x:'Yes' if x>0 else 'No')
df['Active_puchase']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 8945    Yes
# 8946    Yes
# 8947    Yes
# 8948     No
# 8949    Yes
# Name: Active_puchase, Length: 8950, dtype: object

# %%
df['']
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.groupby('Purchase_level')['PURCHASES'].mean().plot(kind='bar',color='skyblue')
plt.title('Purchase vs Purchase level')
plt.show()

# %%
df.groupby('PRC_FULL_PAYMENT')['CREDIT_LIMIT'].mean().plot(kind='bar',color='lightblue')
plt.title('Credit limit vs full payment')
plt.show()

# %%
num_df = df.select_dtypes(include=['float64','int64'])
plt.figure(figsize=(10,8))
sns.heatmap(num_df.corr(),cmap='coolwarm',annot=True,fmt='.2f')
plt.title('Correlation of numbers')
plt.show()

# %%
df.to_csv('Clean_credit_carddata.csv',index=False)

# %%
df.to
